# %% [markdown]
# # chapter 01: Ask ans Answer
# # chapter 02: How to run Python program
# # chapter 03: Hwo do you make program running
# # chapter 04: Intruct python object type
# # chapter 05: Number Type
# # chapter 06: Dynamic type 动态类型
# # chapter 07: String base 字符串基础
# # chapter 08: List and Dict 列表和字典
# # chapter 09: Tuple file and other core type 元组文件和其他核心文件
# # chapter 10: Python Introduction python语句简介

# %%
a = 1
b = 2
a / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-1-547f810cea6a> in <module>
#       1 a = 1
#       2 b = 2
# ----> 3 a / 0
#
# ZeroDivisionError: division by zero

# %%
a, b
# Out:
# (1, 2)

# %%
# 加个括号就可以了
(a +
b)
# Out:
# 3

# %%
c = 1
d = 2
c + 
d
# Out:
#   File "<ipython-input-3-45318486396f>", line 3
#     c +
#         ^
# SyntaxError: invalid syntax

# %%
# 因为上面的错误是语法错误,在运行前就发现了,所以,其实前两行也是没有运行的,所以c是没有定义的
# 语法错误和运行错误是不同的错误类型
c, d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a320f96983df> in <module>
#       1 # 因为上面的错误是语法错误,在运行前就发现了,所以,其实前两行也是没有运行的,所以c是没有定义的
#       2 # 语法错误和运行错误是不同的错误类型
# ----> 3 c, d
#
# NameError: name 'c' is not defined
