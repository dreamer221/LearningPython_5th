# %% [markdown]
# # chapter 01: Ask ans Answer
# # chapter 02: How to run Python program
# # chapter 03: Hwo do you make program running
# # chapter 04: Intruct python object type
# # chapter 05: Number Type
# # chapter 06: Dynamic type 动态类型
# # chapter 07: String base 字符串基础

# %% [markdown]
# ## string base 字符串基础

# %% [markdown]
# ## string value 字符串字面量

# %%
'shrubbery', "shrubbery"
# Out:
# ('shrubbery', 'shrubbery')

# %%
'knight"s', "knighr's"
# Out:
# ('knight"s', "knighr's")

# %%
# no "," will not be a tupel, auto concate to a string 
s = 'knight"s' "knighr's"
print(t)
# Out:
# knight"sknighr's

# %%
title = "Meaning " 'of' " Life"
title
# Out:
# 'Meaning of Life'

# %%
t = 'knight\'s', "knight\"s"
t
# Out:
# ("knight's", 'knight"s')

# %%
print(t[0])
# Out:
# knight's

# %%
print(t[1])
# Out:
# knight"s

# %% [markdown]
# ---------------

# %%
s = 'a\nb\tc'
s
# Out:
# 'a\nb\tc'

# %%
print(s)
# Out:
# a
# b	c

# %%
len(s)
# Out:
# 5

# %% [markdown]
# -----

# %%
s = 'sa\'d\"f\\ksj\
sdfs'
s
# Out:
# 'sa\'d"f\\ksjsdfs'

# %%
print(s)
# Out:
# sa'd"f\ksjsdfs

# %%
'\a' # 不发声音,如果想让听声音,可以运行下面的代码
# Out:
# '\x07'

# %%
import sys
import os

# Windows 系统
if sys.platform == 'win32':
    import winsound
    winsound.Beep(1000, 500)  # 频率1000Hz，持续500ms
    # 或播放系统提示音
#     winsound.MessageBeep()

# macOS 系统
elif sys.platform == 'darwin':
    os.system('afplay /System/Library/Sounds/Ping.aiff 2>/dev/null')

# Linux 系统
else:
    # 尝试使用 beep 命令（可能需要安装）
    os.system('echo -e "\a"')
    # 或使用系统声音
    os.system('paplay /usr/share/sounds/freedesktop/stereo/complete.oga 2>/dev/null')

# %%
import winsound

winsound.Beep(100, 1000) # 频率1000Hz，持续500ms

# %%
# \r \n区别和联系
# \r（Carriage Return，回车，ASCII 13）：把光标移到当前行的开头
# \n（Line Feed，换行，ASCII 10）：把光标移到下一行

# %%
s = 'abcdefg\rABCD\nxyz'
s
# Out:
# 'abcdefg\rABCD\nxyz'

# %%
# 先打印"abcdefg"，回车回到行首，再打印"ABCD"覆盖了"abcd",再移到下一行打印
# 如果是写入文件,则不会覆盖,见下面的写入案例
print(s)
# Out:
# ABCDefg
# xyz

# %%
s = 'a\0b\0c'
s
# Out:
# 'a\x00b\x00c'

# %%
print(s, len(s))
# Out:
# abc 5

# %%
s = '\001\002\03'
s
# Out:
# '\x01\x02\x03'

# %%
print(s, len(s))
# Out:
#  3

# %%
s = 's\tp\na\x00m'
s
# Out:
# 's\tp\na\x00m'

# %%
print(s)
# Out:
# s	p
# am

# %%
len(s)
# Out:
# 7

# %%
print('"\x00"')
# Out:
# ""

# %%
x = 'C:\py'
x
# Out:
# 'C:\\py'

# %%
print(x)
# Out:
# C:\py

# %%
len(x)
# Out:
# 5

# %% [markdown]
# -----------

# %%
f = open('.\new\text.txt', 'w')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-162-4ed173741c63> in <module>
# ----> 1 f = open('.\new\text.txt', 'w')
#
# OSError: [Errno 22] Invalid argument: '.\new\text.txt'

# %%
f = open(r'.\new\text.txt', 'w')
f.write('hello\rworld\nbyebye')
f.close()

# %% [markdown]
# 在cmd中显示内容hello会被覆盖
#
# ![](./new/img1.png)

# %%
f = open(r'.\\new\\text2.txt', 'w')
f.write('dfgdfgdfg')
f.close()

# %%
mantra = """Always look
on the bright
side of the life."""
mantra
# Out:
# 'Always look\non the bright\nside of the life.'

# %%
print(mantra)
# Out:
# Always look
# on the bright
# side of the life.

# %%
menu = """spam   # 注释
eggs  #ditto
"""
menu
# Out:
# 'spam   # 注释\neggs  #ditto\n'

# %%
print(menu)
# Out:
# spam   # 注释
# eggs  #ditto

# %%
s = (
"spam\n"   # zhushi
"eggs\n")
s
# Out:
# 'spam\neggs\n'

# %%
print(s)
# Out:
# spam
# eggs

# %%
x = 1
"""
import os
os.getcwd()
"""
# 上面的暂时不运行
Y = 2

# %%
import os
os.getcwd() # current working directory
# Out:
# 'D:\\MyJupyter\\learning_python-5th\\chapter-07'

# %% [markdown]
# ## Strings in practical applications 实际应用中的字符串

# %%
len('abc')
# Out:
# 3

# %%
'abc' + 'def'
# Out:
# 'abcdef'

# %%
'NI!' * 4
# Out:
# 'NI!NI!NI!NI!'

# %%
print('----------------------------------------')
print('-' * 40)
# Out:
# ----------------------------------------
# ----------------------------------------

# %%
# not auto transform 9 to '9' and then concate
'abc' + 9
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-0b8d4e21a818> in <module>
#       1 # not auto transform 9 to '9' and then concate
# ----> 2 'abc' + 9
#
# TypeError: can only concatenate str (not "int") to str

# %%
myjob = 'hacker'
for c in myjob:
    print(c, end=' ')
# Out:
# h a c k e r

# %%
'k' in myjob
# Out:
# True

# %%
'z' in myjob
# Out:
# False

# %%
'spam' in 'abcspamedf'
# Out:
# True

# %% [markdown]
# ------

# %%
s = 'spam'
s[0], s[-2]
# Out:
# ('s', 'a')

# %%
s[1:3], s[1:], s[:-1]
# Out:
# ('pa', 'pam', 'spa')

# %%
s = 'abcdefghijklmnop'
s[1:10:2]
# Out:
# 'bdfhj'

# %%
s[::2]
# Out:
# 'acegikmo'

# %%
s = 'hello'
s[::-1]
# Out:
# 'olleh'

# %%
s = 'abcdefg'
s[5:1:-1]
# Out:
# 'fedc'

# %%
'spam'[1:3]
# Out:
# 'pa'

# %%
'spam'[slice(1, 3)]
# Out:
# 'pa'

# %%
'spam'[::-1]
# Out:
# 'maps'

# %%
'spam'[slice(None, None, -1)]
# Out:
# 'maps'

# %%
sl = slice(1, 3)
sl
# Out:
# slice(1, 3, None)

# %%
dir(sl)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'indices',
#  'start',
#  'step',
#  'stop']

# %%
sl.start, sl.stop, sl.step
# Out:
# (1, 3, None)

# %%
import sys

sys.argv
# Out:
# ['D:\\software\\anaconda202105\\lib\\site-packages\\ipykernel_launcher.py',
#  '-f',
#  'C:\\Users\\wx\\AppData\\Roaming\\jupyter\\runtime\\kernel-26a8499b-fc49-47b6-a4c9-84ad838f9cd4.json']

# %%
# !python echo.py -a -b -c
# Out:
# Active code page: 65001
# 参数个数: 4
# 参数 0: echo.py
# 参数 1: -a
# 参数 2: -b
# 参数 3: -c

# %% [markdown]
# -----

# %%
'42' + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-5d43c357ae74> in <module>
# ----> 1 '42' + 1
#
# TypeError: can only concatenate str (not "int") to str

# %%
int('42'), str(42)
# Out:
# (42, '42')

# %%
s = repr(42)
type(s), s
# Out:
# (str, '42')

# %%
print(s)
# Out:
# 42

# %%
s1 = str('spam')
s2 = repr('spam')
s1, s2
# Out:
# ('spam', "'spam'")

# %%
print(s1, s2)
# Out:
# spam 'spam'

# %%
S = "42"
I = 1
S + I
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-e8e3411353d7> in <module>
#       1 S = "42"
#       2 I = 1
# ----> 3 S + I
#
# TypeError: can only concatenate str (not "int") to str

# %%
int(S) + I
# Out:
# 43

# %%
S + str(I)
# Out:
# '421'

# %%
str(3.1415), float('1.5')
# Out:
# ('3.1415', 1.5)

# %%
text = '1.234E-10'
float(text)
# Out:
# 1.234e-10

# %%
s = "1 + 2"
eval(s)
# Out:
# 3

# %% [markdown]
# -----

# %%
ord('s')
# Out:
# 115

# %%
ord('一')
# Out:
# 19968

# %%
help(ord)
# Out:
# Help on built-in function ord in module builtins:
#
# ord(c, /)
#     Return the Unicode code point for a one-character string.

# %%
chr(115), chr(19968)
# Out:
# ('s', '一')

# %%
help(chr)
# Out:
# Help on built-in function chr in module builtins:
#
# chr(i, /)
#     Return a Unicode string of one character with ordinal i; 0 <= i <= 0x10ffff.

# %%
S = '5'
S = chr(ord(S) + 1)
S
# Out:
# '6'

# %%
S = chr(ord(S) + 1)
S
# Out:
# '7'

# %%
int('5')
# Out:
# 5

# %%
ord('5'),  ord('0'), ord('5') - ord('0')
# Out:
# (53, 48, 5)

# %%
B = '1101'
I = 0
while B != '':
    I = I * 2 + ( ord(B[0]) - ord('0') )
    print("I:", I)
    B = B[1:]
    print("B:", B)
    print('---------------------')
I
# Out:
# I: 1
# B: 101
# ---------------------
# I: 3
# B: 01
# ---------------------
# I: 6
# B: 1
# ---------------------
# I: 13
# B:
# ---------------------
# 13

# %%
int('1101', 2)
# Out:
# 13

# %%
bin(13)
# Out:
# '0b1101'

# %% [markdown]
# -----

# %%
s = 'spam'
s['0'] = 'x'
s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-1e5afbe902c3> in <module>
#       1 s = 'spam'
# ----> 2 s['0'] = 'x'
#       3 s
#
# TypeError: 'str' object does not support item assignment

# %%
s2 = s + 'SPAM!'
s2
# Out:
# 'spamSPAM!'

# %%
s3 = s2[:4] + '-Burger-' + s2[-1]
s3
# Out:
# 'spam-Burger-!'

# %%
s4 = 'splot'
s5 = s4.replace('pl', 'pamal')
s5
# Out:
# 'spamalot'

# %%
'that is %d %s bird!' % (1, 'dead')
# Out:
# 'that is 1 dead bird!'

# %%
'That is {0} {1} bird!'.format(1, 'dead')
# Out:
# 'That is 1 dead bird!'

# %% [markdown]
# ## string method 字符串方法

# %%
s = 'spam'
idx = s.find('pa')
idx
# Out:
# 1

# %%
s.find('pp')
# Out:
# -1

# %% [markdown]
# ----

# %%
s
# Out:
# 'spam'

# %% [markdown]
# ## String formatted expression 字符串格式化表达式

# %% [markdown]
# ## String formatting method call 字符串格式化方法调用
