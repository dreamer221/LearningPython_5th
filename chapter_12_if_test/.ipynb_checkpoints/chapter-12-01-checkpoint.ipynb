# %%
choice = 'ham'
branch = {'spam': 1.25, 'ham': 1.99, 'eggs': 0.99}
branch
# Out:
# {'spam': 1.25, 'ham': 1.99, 'eggs': 0.99}

# %%
try:
    v = branch['a']
except KeyError:
    print('bad choice')
else:
    print(v)
# Out:
# bad choice

# %%
try:
    v = branch['spam']
except KeyError:
    print('bad choice')
else:
    print('val:', v)
# Out:
# val: 1.25
