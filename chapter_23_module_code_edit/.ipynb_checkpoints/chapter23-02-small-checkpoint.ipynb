# %%
import sys
len(sys.modules)
# Out:
# 750

# %%
from small import x, y
# 这里的x, y 只是 sys.modules['small'].x, sys.modules['small'].y的复制品
# Out:
# runing small.py

# %%
len(sys.modules)
# Out:
# 751

# %%
sys.modules['small'].x, sys.modules['small'].y
# Out:
# (1, [1, 2])

# %%
x = 42
y[0] = 42
x, y
# Out:
# (42, [42, 2])

# %%
sys.modules['small'].x, sys.modules['small'].y
# Out:
# (1, [42, 2])

# %% [markdown]
# - 所以 重新导入后x不变

# %%
import small

# %%
small.x, small.y
# Out:
# (1, [42, 2])
