# %% [markdown]
# # chapter 01: Ask ans Answer
# # chapter 02: How to run Python program
# # chapter 03: Hwo do you make program running
# # chapter 04: Intruct python object type
# # chapter 05: Number Type
# # chapter 06: Dynamic type 动态类型

# %%
a = 3
b = a
print(id(a), id(b))
print('-------------')
a = a + 2
print(a, b)
print(id(a), id(b))
# Out:
# 140706878531440 140706878531440
# -------------
# 5 3
# 140706878531504 140706878531440

# %%
a = 3
b = a

print(id(a), id(b))
print('-------------')
a = 'spam'
print(a, b)
print(id(a), id(b))
# Out:
# 140706878531440 140706878531440
# -------------
# spam 3
# 1441245321200 140706878531440

# %%
x = 42
y = 42
x == y, x is y
# Out:
# (True, True)

# %%
import sys
sys.getrefcount(42)
# Out:
# 33

# %%
x = 'abc'
y = 'abc'
x == y, x is y, sys.getrefcount('abc')
# Out:
# (True, True, 51)

# %%
x = ['abc', 12]
y = ['abc', 12]
x == y, x is y
# Out:
# (True, False)

# %%
import sys

sys.getrefcount(x)
# Out:
# 2

# %%
import sys

sys.getrefcount('啊缴纳罚款瞬间大幅亏损的v奶粉的帅哥啊i')
# Out:
# 3

# %% [markdown]
# # 习题1

# %%
A = 'spam'
B = A
B = 'shrubbery'
A, B
# Out:
# ('spam', 'shrubbery')

# %% [markdown]
# # 习题2

# %%
A = ['spam']
B = A
B[0] = 'shrubbery'
A, B
# Out:
# (['shrubbery'], ['shrubbery'])

# %% [markdown]
# # 习题3

# %%
A = ['spam']
B = A[:]
B[0] = 'shrubbery'
A, B
# Out:
# (['spam'], ['shrubbery'])
