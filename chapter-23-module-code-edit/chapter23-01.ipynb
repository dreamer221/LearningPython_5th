# %%
import module1

# %%
module1.printer('Hello World!')
# Out:
# Hello World!

# %%
dir(module1)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'printer']

# %%
from module1 import printer
printer("asd")
# Out:
# asd

# %%
from module1 import *

# %%
printer("dfgdr")
# Out:
# dfgdr

# %%
import simple
# Out:
# hello

# %%
simple.spam
# Out:
# 1

# %%
simple.spam = 2
simple.spam
# Out:
# 2

# %%
import simple

simple.spam
# Out:
# 2

# %%
# Python 3.4+
import importlib 
importlib.reload(simple)

simple.spam
# Out:
# hello
# 1

# %% [markdown]
# ----

# %%
from small import x, y

x, y
# Out:
# (1, [1, 2])

# %%
x = 2
y[0] = 42
x, y
# Out:
# (2, [42, 2])

# %%
import small

# %%
small.x, small.y
# Out:
# (1, [42, 2])
