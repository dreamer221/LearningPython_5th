# %%
import module1

# %%
module1.printer('Hello World!')
# Out:
# Hello World!

# %%
dir(module1)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'printer']

# %%
from module1 import printer
printer("asd")
# Out:
# asd

# %%
from module1 import *

# %%
printer("dfgdr")
# Out:
# dfgdr

# %% [markdown]
# ----

# %%
import sys
len(sys.modules), sys.modules.get('simple', 666)
# Out:
# (752, 666)

# %%
import simple
# Out:
# hello

# %%
len(sys.modules), sys.modules.get('simple', 666)
# Out:
# (753,
#  <module 'simple' from 'D:\\MyJupyter\\learning_python-5th\\chapter-23-module-code-edit\\simple.py'>)

# %%
simple.spam
# Out:
# 1

# %%
simple.spam = 2
simple.spam
# Out:
# 2

# %%
import simple # 不做任何操作

simple.spam # 还是上面改后的 2
# Out:
# 1

# %%
# Python 3.4+
import importlib 
importlib.reload(simple) # 重新导入

simple.spam
# Out:
# hello
# 1

# %% [markdown]
# ----

# %%
dir(simple)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'spam']

# %%
simple.__dict__.keys()
# Out:
# dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__file__', '__cached__', '__builtins__', 'spam'])

# %%
for k in simple.__dict__.keys():
    print(k, simple.__dict__[k])
    print('=======================')
# Out:
# __name__ simple
# ...
# __doc__ None
# ...
# __package__
# ...
# __loader__ <_frozen_importlib_external.SourceFileLoader object at 0x0000015042384820>
# ...
# __spec__ ModuleSpec(name='simple', loader=<_frozen_importlib_external.SourceFileLoader object at 0x0000015042384820>, origin='D:\\MyJupyter\\learning_python-5th\\chapter-23-module-code-edit\\simple.py')
# ...
# __file__ D:\MyJupyter\learning_python-5th\chapter-23-module-code-edit\simple.py
# ...
# __cached__ D:\MyJupyter\learning_python-5th\chapter-23-module-code-edit\__pycache__\simple.cpython-38.pyc
# ...
