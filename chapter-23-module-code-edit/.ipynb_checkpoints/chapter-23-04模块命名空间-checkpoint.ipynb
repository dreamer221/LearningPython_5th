# %%
import moudle2
# Out:
# starting to load ...
# done loading.

# %%
moudle2.sys
# Out:
# <module 'sys' (built-in)>

# %%
import sys

# %%
sys is moudle2.sys
# Out:
# True

# %%
moudle2.name
# Out:
# 42

# %%
moudle2.func
# Out:
# <function moudle2.func()>

# %%
moudle2.kclass
# Out:
# moudle2.kclass

# %%
moudle2.__dict__.keys()
# Out:
# dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__file__', '__cached__', '__builtins__', 'sys', 'name', 'func', 'kclass'])

# %%
list(moudle2.__dict__.keys())
# Out:
# ['__name__',
#  '__doc__',
#  '__package__',
#  '__loader__',
#  '__spec__',
#  '__file__',
#  '__cached__',
#  '__builtins__',
#  'sys',
#  'name',
#  'func',
#  'kclass']

# %%
[n for n in list(moudle2.__dict__.keys()) if not n.startswith('__')]
# Out:
# ['sys', 'name', 'func', 'kclass']

# %%
[n for n in list(moudle2.__dict__.keys()) if n.startswith('__')]
# Out:
# ['__name__',
#  '__doc__',
#  '__package__',
#  '__loader__',
#  '__spec__',
#  '__file__',
#  '__cached__',
#  '__builtins__']

# %%
moudle2.__dict__['name']
# Out:
# 42

# %%
moudle2.name
# Out:
# 42

# %% [markdown]
# -----

# %%
# !python modb.py
# Out:
# Active code page: 65001
# 11 99

# %% [markdown]
# -------

# %%
# !python mod1.py
# Out:
# Active code page: 65001
# 2 3
# 1 2 3

# %% [markdown]
# # 重新加载模块

# %%
import small
# Out:
# runing small.py

# %%
import small

# %%
from imp import reload

# %%
small2 = reload(small)
# Out:
# runing small.py

# %%
small is small2
# Out:
# True

# %% [markdown]
# # reload

# %%
import changer

changer.printer()
# Out:
# First version

# %%
# 修改 changer.py中的内容

# %%
import changer
changer.printer()
# Out:
# First version

# %%
from imp import reload
reload(changer)
# Out:
# <module 'changer' from 'D:\\MyJupyter\\learning_python-5th\\chapter-23-module-code-edit\\changer.py'>

# %%
changer.printer()
# Out:
# reloaded: After version
