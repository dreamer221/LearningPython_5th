# %%
seq = [1, 2, 3, 4]
a, b, c, *d = seq
a, b, c, d
# Out:
# (1, 2, 3, [4])

# %%
a, b, c, d, *e = seq
a, b, c, d, e
# Out:
# (1, 2, 3, 4, [])

# %%
a, b, *c, d, e = seq
a, b, c, d, e
# Out:
# (1, 2, [], 3, 4)

# %%
a, *b, c, *d = seq
a, b, c, d
# Out:
#   File "<ipython-input-4-756b5b508c2d>", line 1
#     a, *b, c, *d = seq
#     ^
# SyntaxError: two starred expressions in assignment

# %%
a, b = seq
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-8a1b49c05b5f> in <module>
# ----> 1 a, b = seq
#
# ValueError: too many values to unpack (expected 2)

# %%
*a = seq
a
# Out:
#   File "<ipython-input-6-a56c709d043f>", line 1
#     *a = seq
#     ^
# SyntaxError: starred assignment target must be in a list or tuple

# %%
*a, = seq
a
# Out:
# [1, 2, 3, 4]

# %%
## 增量赋值

# %%
x = 3
x <<= 3
x
# Out:
# 24

# %%
x >> 4
# Out:
# 1

# %%
2 >> 2
# Out:
# 0

# %%
2 >> 1
# Out:
# 1

# %%
3 >> 1
# Out:
# 1

# %%
l = []
l = l + 'spam'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-bf8f4c3bc399> in <module>
#       1 l = []
# ----> 2 l = l + 'spam'
#
# TypeError: can only concatenate list (not "str") to list

# %%
l = []
l += 'spam'
l
# Out:
# ['s', 'p', 'a', 'm']

# %%
l += 'spam'
l
# Out:
# ['s', 'p', 'a', 'm', 's', 'p', 'a', 'm']

# %%
l = l + 'spam'
l
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-2cee35df5ef1> in <module>
# ----> 1 l = l + 'spam'
#       2 l
#
# TypeError: can only concatenate list (not "str") to list

# %%
import sys

sys.stdout.write('hello world \n')
# Out:
# hello world

# %%
x = 'hello'
y = 'world'
print(x, y)
# Out:
# hello world

# %%
sys.stdout.write(x + ' ' + y + '\n')
# Out:
# hello world

# %%
sys.stdout

# %%
sys.stdout = open('log.txt', 'a')
sys.stdout
# Out:
# <_io.TextIOWrapper name='log.txt' mode='a' encoding='cp936'>

# %%
print(x, y)

# %%
print(x, y)

# %% [markdown]
# ---

# %%
sys.stderr.write('Err...' + '\n')
# Out:
# Err...
