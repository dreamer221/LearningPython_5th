# %%
import pandas as pd

# %%
df = pd.DataFrame()
df['a'] = [1, 2, 3]
df['b'] = [4, 5, 6]
df
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %%
dic = df.iloc[0].to_dict()
dic
# Out:
# {'a': 1, 'b': 4}

# %%
order = {}

# %%
class Strate:
    def __init__(self, ):
        self.order_li = []
        self.hold_dic = {"cash":pd.DataFrame()}
        
    def buy():
        pass
    
    def sale():
        pass
