# %%
from mypack import a
# Out:
# my-string
# string-name1 string-name2

# %%
a.spam
# Out:
# <module 'mypack.spam' from 'D:\\MyJupyter\\learning_python-5th\\chapter-24-module-package\\relative_demo\\mypack\\spam.py'>

# %%
a.spam.name
# Out:
# 'spam-name'

# %%
a.name1
# Out:
# 'string-name1'

# %%
a.name2
# Out:
# 'string-name2'
