# %%
import dir1.dir2.mod
# Out:
# dir1 init
# dir2 init
# in mod.py

# %%
import dir1.dir2.mod

# %%
from imp import reload

reload(dir1)
# Out:
# dir1 init
# <module 'dir1' from 'D:\\MyJupyter\\learning_python-5th\\chapter-24-module-package\\dir-demo\\dir1\\__init__.py'>

# %%
reload(dir1.dir2)
# Out:
# dir2 init
# <module 'dir1.dir2' from 'D:\\MyJupyter\\learning_python-5th\\chapter-24-module-package\\dir-demo\\dir1\\dir2\\__init__.py'>

# %%
dir1
# Out:
# <module 'dir1' from 'D:\\MyJupyter\\learning_python-5th\\chapter-24-module-package\\dir-demo\\dir1\\__init__.py'>

# %%
dir2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-7710802289b3> in <module>
# ----> 1 dir2
#
# NameError: name 'dir2' is not defined

# %%
dir1.dir2
# Out:
# <module 'dir1.dir2' from 'D:\\MyJupyter\\learning_python-5th\\chapter-24-module-package\\dir-demo\\dir1\\dir2\\__init__.py'>

# %%
dir1.dir2.mod
# Out:
# <module 'dir1.dir2.mod' from 'D:\\MyJupyter\\learning_python-5th\\chapter-24-module-package\\dir-demo\\dir1\\dir2\\mod.py'>

# %%
dir1.x
# Out:
# 1

# %%
dir1.dir2.y
# Out:
# 2

# %%
dir1.dir2.mod.z
# Out:
# 3
