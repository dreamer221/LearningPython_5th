# %%
import system1.utilities
import system2.utilities

system1.utilities.function('spam')
system2.utilities.function('spam')
# Out:
# system1-utilities'function: spam
# system2-utilities'function: spam
