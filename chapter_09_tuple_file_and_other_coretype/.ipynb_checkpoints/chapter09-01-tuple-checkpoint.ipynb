# %%
T = ('cc', 'aa', 'dd', 'bb')
T
# Out:
# ('cc', 'aa', 'dd', 'bb')

# %%
li = sorted(T)
li
# Out:
# ['aa', 'bb', 'cc', 'dd']

# %%
help(sorted)
# Out:
# Help on built-in function sorted in module builtins:
#
# sorted(iterable, /, *, key=None, reverse=False)
#     Return a new list containing all items from the iterable in ascending order.
#
#     A custom key function can be supplied to customize the sort order, and the
#     reverse flag can be set to request the result in descending order.

# %%
s = {3, 2, 5, 1}
s
# Out:
# {1, 2, 3, 5}

# %%
sorted(s)
# Out:
# [1, 2, 3, 5]

# %% [markdown]
# - sorted 返回的就只是列表

# %%
T = (1, 2, 3, 4, 5)
L = [x + 20 for x in T]
L
# Out:
# [21, 22, 23, 24, 25]

# %%
g = (x + 20 for x in T)
g
# Out:
# <generator object <genexpr> at 0x0000029FADEA80B0>

# %%
g.next()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-7dbbdfed0980> in <module>
# ----> 1 g.next()
#
# AttributeError: 'generator' object has no attribute 'next'

# %%
dir(g)
# Out:
# ['__class__',
#  '__del__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'close',
#  'gi_code',
#  'gi_frame',
#  'gi_running',
#  'gi_yieldfrom',
#  'send',
#  'throw']

# %%
next(g)
# Out:
# 21

# %%
next(g)
# Out:
# 22

# %%
t = (1, 2, 3, 4, 1)
print(t.index(1)) # 1's index
print(t.index(4, 3) ) # 4's index from 3,and include 3
print(t.index(2, 3)) # 2's index >= 3,there is no 2
# Out:
# 0
# 3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-6f50338f68cf> in <module>
#       2 print(t.index(1))
#       3 print(t.index(4, 3) )
# ----> 4 print(t.index(2, 3))
#
# ValueError: tuple.index(x): x not in tuple

# %%
t = (2, 2, 3, 5, 2, 6, 8, 2, 4, 2)
t
# Out:
# (2, 2, 3, 5, 2, 6, 8, 2, 4, 2)

# %%
t.index(2)
# Out:
# 0

# %%
t.index(2, 1)
# Out:
# 1

# %%
t.index(2, 4), t.index(2, 5)
# Out:
# (4, 7)

# %%
help(t.index)
# Out:
# Help on built-in function index:
#
# index(value, start=0, stop=9223372036854775807, /) method of builtins.tuple instance
#     Return first index of value.
#
#     Raises ValueError if the value is not present.

# %%
## 重访记录: 有名元组

# %%
bob = dict(name='Bob', age = 40.5, job=['dev', 'mgr'])
bob
# Out:
# {'name': 'Bob', 'age': 40.5, 'job': ['dev', 'mgr']}

# %%
bob.keys(), bob.values()
# Out:
# (dict_keys(['name', 'age', 'job']), dict_values(['Bob', 40.5, ['dev', 'mgr']]))

# %%
tuple(bob.keys()), tuple(bob.values())
# Out:
# (('name', 'age', 'job'), ('Bob', 40.5, ['dev', 'mgr']))

# %%
list(bob.items())
# Out:
# [('name', 'Bob'), ('age', 40.5), ('job', ['dev', 'mgr'])]

# %% [markdown]
# ----

# %%
from collections import namedtuple

# %%
People = namedtuple('People', ['name', 'age', 'job'])
type(People)
# Out:
# type

# %%
People
# Out:
# __main__.People

# %%
p1 = People('Tom', age=40.5, job=['dev', 'ngr'])
p1
# Out:
# People(name='Tom', age=40.5, job=['dev', 'ngr'])

# %%
print(dir(p1))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmul__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '_asdict', '_field_defaults', '_fields', '_fields_defaults', '_make', '_replace', 'age', 'count', 'index', 'job', 'name']

# %%
p1[0], p1[1], p1[2]
# Out:
# ('Tom', 40.5, ['dev', 'ngr'])

# %%
p1.name
# Out:
# 'Tom'

# %%
p1.age, p1.job
# Out:
# (40.5, ['dev', 'ngr'])

# %%
d = p1._asdict()
d
# Out:
# {'name': 'Tom', 'age': 40.5, 'job': ['dev', 'ngr']}

# %%
help(p1._asdict)
# Out:
# Help on method _asdict in module collections:
#
# _asdict() method of __main__.People instance
#     Return a new dict which maps field names to their values.

# %%
type(d)
# Out:
# dict

# %%
d
# Out:
# {'name': 'Tom', 'age': 40.5, 'job': ['dev', 'ngr']}
